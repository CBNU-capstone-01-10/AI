# %%
import cv2

import torch
import sys
import matplotlib.pyplot as plt

from ultralytics import YOLO

# %%
print(torch.__version__)
print(sys.version)
print(sys.executable)
print(torch.backends.cudnn.version())
# Out:
# 2.4.0+cu121
# 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# d:\PROGRAMMING\AI_HDD\SenierProject\Yolo\.venv\Scripts\python.exe
# 90100

# %%
model = YOLO("../pretrained/yolov8m.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8m.pt to 'pretrained\yolov8m.pt'...
# 100%|██████████| 49.7M/49.7M [00:03<00:00, 15.5MB/s]

# %%
img = cv2.imread("../dataset/test/test1.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
results = model(img)
# Out:
# 0: 448x640 1 person, 1 car, 1 chair, 151.4ms
# Speed: 3.2ms preprocess, 151.4ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
plt.imshow(results[0].plot())
plt.show()
